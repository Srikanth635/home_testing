# %%
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

plt.figure(figsize=(16, 14))
v = venn3(subsets=(8, 8, 8, 10, 10, 10, 10), set_labels=('', '', ''), set_colors=("orange", "green", "purple"), alpha=0.9)
# venn3_circles(subsets=(10, 10, 10, 10, 10, 10, 10))

v.get_label_by_id('100').set_text("Human Action Science (H)")
v.get_label_by_id('010').set_text("Knowledge Representation"
                                  "\n & Reasoning (P)")
v.get_label_by_id('001').set_text("Robotics & AI (R)")
v.get_label_by_id('110').set_text("""
Cognitive models of reasoning
Symbolic representation
Modeling human intent
""")
v.get_label_by_id('011').set_text("""
Embodied knowledge representation
AI-driven task planning
Symbolic reasoning in robotics
""")
v.get_label_by_id('101').set_text("""
Human-robot interaction
Modeling motor skills
Cognitive architectures
""")
v.get_label_by_id('111').set_text("""
Co-construction in collaboration
Adaptive robots
AI-powered reasoning in robotics
""")

plt.title("Intersection of venn diagrams")
plt.show()
